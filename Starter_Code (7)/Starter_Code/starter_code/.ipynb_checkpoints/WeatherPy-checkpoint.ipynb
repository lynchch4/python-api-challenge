# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 637

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | college
# Processing Record 2 of Set 1 | kidero
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | jardim
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | keti bandar
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | nadym
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | karratha
# Processing Record 16 of Set 1 | half moon bay
# Processing Record 17 of Set 1 | dingle
# Processing Record 18 of Set 1 | vaksdal
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | arequipa
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | mende
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | sambava
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | santa marinella
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | zaria
# Processing Record 36 of Set 1 | hasaki
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | nakhon thai
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | ariquemes
# Processing Record 45 of Set 1 | tevaitoa
# Processing Record 46 of Set 1 | malanje
# Processing Record 47 of Set 1 | komsomolskiy
# Processing Record 48 of Set 1 | shagonar
# Processing Record 49 of Set 1 | steinbach
# Processing Record 50 of Set 1 | flinders
# Processing Record 0 of Set 2 | dikson
# Processing Record 1 of Set 2 | palmer
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | gravelbourg
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | chiang klang
# Processing Record 9 of Set 2 | bestobe
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | drovyanaya
# Processing Record 12 of Set 2 | camana
# Processing Record 13 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 2 | bosaso
# Processing Record 15 of Set 2 | okha
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | jieshi
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | shimoga
# Processing Record 23 of Set 2 | adrar
# Processing Record 24 of Set 2 | arman
# Processing Record 25 of Set 2 | pingliang
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | valparaiso
# Processing Record 29 of Set 2 | saint-augustin
# Processing Record 30 of Set 2 | dunedin
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | hindoria
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | hovd
# Processing Record 42 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 2 | mayumba
# Processing Record 44 of Set 2 | waipawa
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | mandurah
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | khatanga
# Processing Record 0 of Set 3 | chernyshevskiy
# Processing Record 1 of Set 3 | kloulklubed
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | nouadhibou
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 3 | dafeng
# Processing Record 9 of Set 3 | mutare
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | mira
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 3 | santa elena
# Processing Record 15 of Set 3 | auki
# Processing Record 16 of Set 3 | rawson
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | kaeo
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | thomasville
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | alihe
# Processing Record 23 of Set 3 | marsh harbour
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | moose factory
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | sept-iles
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | harboore
# Processing Record 30 of Set 3 | namatanai
# Processing Record 31 of Set 3 | natal
# Processing Record 32 of Set 3 | muisne
# Processing Record 33 of Set 3 | merauke
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | fukue
# Processing Record 36 of Set 3 | baltasi
# Processing Record 37 of Set 3 | kavaratti
# Processing Record 38 of Set 3 | dakar
# Processing Record 39 of Set 3 | bulungu
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | bilma
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | veraval
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | puttur
# Processing Record 47 of Set 3 | bandarbeyla
# Processing Record 48 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 3 | am timan
# Processing Record 0 of Set 4 | souillac
# Processing Record 1 of Set 4 | samarai
# Processing Record 2 of Set 4 | teguise
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | acajutla
# Processing Record 5 of Set 4 | cherskiy
# Processing Record 6 of Set 4 | char bhadrasan
# Processing Record 7 of Set 4 | quatre cocos
# Processing Record 8 of Set 4 | platonovka
# Processing Record 9 of Set 4 | linxia
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | montoro
# Processing Record 12 of Set 4 | tilichiki
# Processing Record 13 of Set 4 | grand gaube
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | te anau
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | bowen
# Processing Record 18 of Set 4 | vaini
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | adela
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | turkistan
# Processing Record 23 of Set 4 | praia
# Processing Record 24 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | padang
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | kindu
# Processing Record 28 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 4 | kungurtug
# Processing Record 30 of Set 4 | kahului
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | bojnurd
# Processing Record 33 of Set 4 | krasnoselkup
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | port elizabeth
# Processing Record 36 of Set 4 | mackay
# Processing Record 37 of Set 4 | morondava
# Processing Record 38 of Set 4 | henties bay
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | weligama
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | baruun-urt
# Processing Record 43 of Set 4 | bandar-e lengeh
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 4 | acapulco
# Processing Record 49 of Set 4 | lorengau
# Processing Record 0 of Set 5 | tripoli
# Processing Record 1 of Set 5 | erenhot
# Processing Record 2 of Set 5 | broken hill
# Processing Record 3 of Set 5 | beringovskiy
# Processing Record 4 of Set 5 | novyy urgal
# Processing Record 5 of Set 5 | arawa
# Processing Record 6 of Set 5 | kang
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | sechura
# Processing Record 9 of Set 5 | raudeberg
# Processing Record 10 of Set 5 | macia
# Processing Record 11 of Set 5 | qaanaaq
# Processing Record 12 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | lonevag
# Processing Record 15 of Set 5 | weinan
# Processing Record 16 of Set 5 | bolshaya irba
# City not found. Skipping...
# Processing Record 17 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 5 | okmulgee
# Processing Record 19 of Set 5 | tigre
# Processing Record 20 of Set 5 | bar harbor
# Processing Record 21 of Set 5 | pevek
# Processing Record 22 of Set 5 | serta
# Processing Record 23 of Set 5 | rocha
# Processing Record 24 of Set 5 | morant bay
# Processing Record 25 of Set 5 | sola
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | lasa
# Processing Record 29 of Set 5 | maumere
# Processing Record 30 of Set 5 | walvis bay
# Processing Record 31 of Set 5 | pimentel
# Processing Record 32 of Set 5 | sibolga
# Processing Record 33 of Set 5 | sisimiut
# Processing Record 34 of Set 5 | floro
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | mutsu
# Processing Record 37 of Set 5 | provideniya
# Processing Record 38 of Set 5 | manokwari
# Processing Record 39 of Set 5 | eydhafushi
# Processing Record 40 of Set 5 | mitu
# Processing Record 41 of Set 5 | castro
# Processing Record 42 of Set 5 | amboasary
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | kapit
# Processing Record 45 of Set 5 | olafsvik
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | port hedland
# Processing Record 48 of Set 5 | zhigansk
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 0 of Set 6 | ruteng
# Processing Record 1 of Set 6 | atuona
# Processing Record 2 of Set 6 | hualmay
# Processing Record 3 of Set 6 | xiongzhou
# Processing Record 4 of Set 6 | plettenberg bay
# Processing Record 5 of Set 6 | biak
# Processing Record 6 of Set 6 | aripuana
# Processing Record 7 of Set 6 | ilhabela
# Processing Record 8 of Set 6 | itapaci
# Processing Record 9 of Set 6 | asheboro
# Processing Record 10 of Set 6 | fuerte olimpo
# Processing Record 11 of Set 6 | ladnun
# Processing Record 12 of Set 6 | tereze
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | ganta
# Processing Record 15 of Set 6 | vostok
# Processing Record 16 of Set 6 | oktyabrskiy
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | awjilah
# Processing Record 21 of Set 6 | lalmohan
# Processing Record 22 of Set 6 | aklavik
# Processing Record 23 of Set 6 | yaan
# Processing Record 24 of Set 6 | matara
# Processing Record 25 of Set 6 | hambantota
# Processing Record 26 of Set 6 | kirkwall
# Processing Record 27 of Set 6 | atka
# City not found. Skipping...
# Processing Record 28 of Set 6 | ribeira grande
# Processing Record 29 of Set 6 | rocky mountain house
# Processing Record 30 of Set 6 | laguna
# Processing Record 31 of Set 6 | cootehill
# Processing Record 32 of Set 6 | grants
# Processing Record 33 of Set 6 | flin flon
# Processing Record 34 of Set 6 | maniwaki
# Processing Record 35 of Set 6 | elsterwerda
# Processing Record 36 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 6 | cayenne
# Processing Record 38 of Set 6 | innisfail
# Processing Record 39 of Set 6 | paralimni
# Processing Record 40 of Set 6 | annau
# Processing Record 41 of Set 6 | gimli
# Processing Record 42 of Set 6 | north bend
# Processing Record 43 of Set 6 | maruko
# Processing Record 44 of Set 6 | tombouctou
# Processing Record 45 of Set 6 | bataipora
# Processing Record 46 of Set 6 | vila franca do campo
# Processing Record 47 of Set 6 | rajapur
# Processing Record 48 of Set 6 | poronaysk
# Processing Record 49 of Set 6 | aleksin
# Processing Record 0 of Set 7 | moses lake
# Processing Record 1 of Set 7 | puerto colombia
# Processing Record 2 of Set 7 | nalut
# Processing Record 3 of Set 7 | jingdezhen
# Processing Record 4 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 5 of Set 7 | ereymentau
# Processing Record 6 of Set 7 | manggar
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | surab
# Processing Record 9 of Set 7 | ayios serafim
# Processing Record 10 of Set 7 | derbent
# Processing Record 11 of Set 7 | kununurra
# Processing Record 12 of Set 7 | rietavas
# Processing Record 13 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 7 | manturovo
# Processing Record 15 of Set 7 | george
# Processing Record 16 of Set 7 | iqaluit
# Processing Record 17 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 18 of Set 7 | hobyo
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 7 | sabang
# Processing Record 22 of Set 7 | jackson
# Processing Record 23 of Set 7 | janow lubelski
# Processing Record 24 of Set 7 | angoche
# Processing Record 25 of Set 7 | ambilobe
# Processing Record 26 of Set 7 | sobolevo
# Processing Record 27 of Set 7 | mbeya
# Processing Record 28 of Set 7 | nuevo progreso
# Processing Record 29 of Set 7 | haines junction
# Processing Record 30 of Set 7 | kieta
# Processing Record 31 of Set 7 | vilhena
# Processing Record 32 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 7 | wajima
# Processing Record 34 of Set 7 | cockburn town
# Processing Record 35 of Set 7 | bereda
# Processing Record 36 of Set 7 | lokosovo
# Processing Record 37 of Set 7 | broome
# Processing Record 38 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 7 | vangaindrano
# Processing Record 40 of Set 7 | mehamn
# Processing Record 41 of Set 7 | fairbanks
# Processing Record 42 of Set 7 | voskresenskoye
# Processing Record 43 of Set 7 | hami
# Processing Record 44 of Set 7 | chadan
# Processing Record 45 of Set 7 | ales
# Processing Record 46 of Set 7 | sinnamary
# Processing Record 47 of Set 7 | santa cruz
# Processing Record 48 of Set 7 | xingyi
# Processing Record 49 of Set 7 | vao
# Processing Record 0 of Set 8 | nuuk
# Processing Record 1 of Set 8 | mamallapuram
# Processing Record 2 of Set 8 | upernavik
# Processing Record 3 of Set 8 | yingkou
# Processing Record 4 of Set 8 | atchison
# Processing Record 5 of Set 8 | batagay-alyta
# Processing Record 6 of Set 8 | cortez
# Processing Record 7 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 8 of Set 8 | lompoc
# Processing Record 9 of Set 8 | severo-kurilsk
# Processing Record 10 of Set 8 | boa vista
# Processing Record 11 of Set 8 | ngunguru
# Processing Record 12 of Set 8 | sao joao da barra
# Processing Record 13 of Set 8 | alyangula
# Processing Record 14 of Set 8 | staraya poltavka
# Processing Record 15 of Set 8 | san juan
# Processing Record 16 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | neiafu
# Processing Record 19 of Set 8 | ahipara
# Processing Record 20 of Set 8 | bandar
# Processing Record 21 of Set 8 | buluang
# Processing Record 22 of Set 8 | troitskoye
# Processing Record 23 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 8 | cap malheureux
# Processing Record 26 of Set 8 | port lincoln
# Processing Record 27 of Set 8 | marystown
# Processing Record 28 of Set 8 | huai thalaeng
# Processing Record 29 of Set 8 | westport
# Processing Record 30 of Set 8 | ilulissat
# Processing Record 31 of Set 8 | nagapattinam
# Processing Record 32 of Set 8 | angra
# City not found. Skipping...
# Processing Record 33 of Set 8 | lagoa
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | qesarya
# Processing Record 36 of Set 8 | tonneins
# Processing Record 37 of Set 8 | opuwo
# Processing Record 38 of Set 8 | san andres
# Processing Record 39 of Set 8 | namibe
# Processing Record 40 of Set 8 | beyneu
# Processing Record 41 of Set 8 | kitimat
# Processing Record 42 of Set 8 | hervey bay
# Processing Record 43 of Set 8 | warrnambool
# Processing Record 44 of Set 8 | tres arroyos
# Processing Record 45 of Set 8 | nanakuli
# Processing Record 46 of Set 8 | molfetta
# Processing Record 47 of Set 8 | kansanshi
# Processing Record 48 of Set 8 | oussouye
# Processing Record 49 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 0 of Set 9 | aegviidu
# Processing Record 1 of Set 9 | dzilam gonzalez
# Processing Record 2 of Set 9 | naples
# Processing Record 3 of Set 9 | xichang
# Processing Record 4 of Set 9 | piacabucu
# Processing Record 5 of Set 9 | aquiraz
# Processing Record 6 of Set 9 | maracacume
# Processing Record 7 of Set 9 | providencia
# Processing Record 8 of Set 9 | ilo
# Processing Record 9 of Set 9 | gonbad-e qabus
# Processing Record 10 of Set 9 | remanso
# Processing Record 11 of Set 9 | gawler
# Processing Record 12 of Set 9 | antofagasta
# Processing Record 13 of Set 9 | huejuquilla el alto
# Processing Record 14 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 9 | blagoyevo
# Processing Record 16 of Set 9 | hefei
# Processing Record 17 of Set 9 | vanavara
# Processing Record 18 of Set 9 | peniche
# Processing Record 19 of Set 9 | dekar
# Processing Record 20 of Set 9 | padron
# Processing Record 21 of Set 9 | golaesti
# Processing Record 22 of Set 9 | orlik
# Processing Record 23 of Set 9 | kandrian
# Processing Record 24 of Set 9 | nome
# Processing Record 25 of Set 9 | namwala
# Processing Record 26 of Set 9 | madimba
# Processing Record 27 of Set 9 | niquelandia
# Processing Record 28 of Set 9 | ikryanoye
# Processing Record 29 of Set 9 | kajaani
# Processing Record 30 of Set 9 | lakatoro
# Processing Record 31 of Set 9 | saint-georges
# Processing Record 32 of Set 9 | gezing
# Processing Record 33 of Set 9 | sorland
# Processing Record 34 of Set 9 | poplar bluff
# Processing Record 35 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 9 | piacenza
# Processing Record 37 of Set 9 | zhezkazgan
# Processing Record 38 of Set 9 | mosquera
# Processing Record 39 of Set 9 | sinazongwe
# Processing Record 40 of Set 9 | pacific grove
# Processing Record 41 of Set 9 | salekhard
# Processing Record 42 of Set 9 | pemangkat
# Processing Record 43 of Set 9 | evensk
# Processing Record 44 of Set 9 | kjollefjord
# Processing Record 45 of Set 9 | mareeba
# Processing Record 46 of Set 9 | la ronge
# Processing Record 47 of Set 9 | saint george
# Processing Record 48 of Set 9 | ponnani
# Processing Record 49 of Set 9 | hede
# Processing Record 0 of Set 10 | yarim
# Processing Record 1 of Set 10 | liverpool
# Processing Record 2 of Set 10 | erzin
# Processing Record 3 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 10 | mount gambier
# Processing Record 5 of Set 10 | kamenka
# Processing Record 6 of Set 10 | canton
# Processing Record 7 of Set 10 | altamira
# Processing Record 8 of Set 10 | san cristobal
# Processing Record 9 of Set 10 | porto santo
# Processing Record 10 of Set 10 | zhuhai
# Processing Record 11 of Set 10 | nioro
# Processing Record 12 of Set 10 | svetlogorsk
# Processing Record 13 of Set 10 | kenai
# Processing Record 14 of Set 10 | chorley
# Processing Record 15 of Set 10 | mpika
# Processing Record 16 of Set 10 | roma
# Processing Record 17 of Set 10 | dhidhdhoo
# Processing Record 18 of Set 10 | itupiranga
# Processing Record 19 of Set 10 | yar-sale
# Processing Record 20 of Set 10 | maceio
# Processing Record 21 of Set 10 | yerbogachen
# Processing Record 22 of Set 10 | mayo
# Processing Record 23 of Set 10 | papara
# Processing Record 24 of Set 10 | halifax
# Processing Record 25 of Set 10 | balma
# Processing Record 26 of Set 10 | santa rosa
# Processing Record 27 of Set 10 | ketchikan
# Processing Record 28 of Set 10 | chumikan
# Processing Record 29 of Set 10 | puerto cabezas
# Processing Record 30 of Set 10 | la crosse
# Processing Record 31 of Set 10 | lakselv
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 10 | shenjiamen
# Processing Record 35 of Set 10 | bakel
# Processing Record 36 of Set 10 | le vauclin
# Processing Record 37 of Set 10 | hirara
# Processing Record 38 of Set 10 | macau
# Processing Record 39 of Set 10 | kirsanov
# Processing Record 40 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 10 | muskogee
# Processing Record 42 of Set 10 | de land
# Processing Record 43 of Set 10 | zirandaro
# Processing Record 44 of Set 10 | grindavik
# Processing Record 45 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 10 | ortega
# Processing Record 47 of Set 10 | san pedro
# Processing Record 48 of Set 10 | uvira
# Processing Record 49 of Set 10 | shubarshi
# Processing Record 0 of Set 11 | manuk mangkaw
# Processing Record 1 of Set 11 | palu
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | goure
# Processing Record 4 of Set 11 | dieppe
# Processing Record 5 of Set 11 | bilibino
# Processing Record 6 of Set 11 | milove
# Processing Record 7 of Set 11 | bathsheba
# Processing Record 8 of Set 11 | arlit
# Processing Record 9 of Set 11 | gambela
# Processing Record 10 of Set 11 | tomatlan
# Processing Record 11 of Set 11 | seaham
# Processing Record 12 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 13 of Set 11 | shingu
# Processing Record 14 of Set 11 | akyab
# Processing Record 15 of Set 11 | talcahuano
# Processing Record 16 of Set 11 | port macquarie
# Processing Record 17 of Set 11 | khandyga
# Processing Record 18 of Set 11 | sungaipenuh
# Processing Record 19 of Set 11 | alta floresta
# Processing Record 20 of Set 11 | fuerte
# Processing Record 21 of Set 11 | caxias
# Processing Record 22 of Set 11 | barreirinha
# Processing Record 23 of Set 11 | les escoumins
# Processing Record 24 of Set 11 | mildura
# Processing Record 25 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 11 | camacha
# Processing Record 27 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 11 | igarka
# Processing Record 29 of Set 11 | caibarien
# Processing Record 30 of Set 11 | husavik
# Processing Record 31 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 32 of Set 11 | koshurnikovo
# Processing Record 33 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 11 | jalu
# Processing Record 35 of Set 11 | camopi
# Processing Record 36 of Set 11 | port keats
# Processing Record 37 of Set 11 | margate
# Processing Record 38 of Set 11 | lannion
# Processing Record 39 of Set 11 | whitehorse
# Processing Record 40 of Set 11 | luganville
# Processing Record 41 of Set 11 | san lorenzo
# Processing Record 42 of Set 11 | katobu
# Processing Record 43 of Set 11 | port antonio
# Processing Record 44 of Set 11 | tlahualilo
# City not found. Skipping...
# Processing Record 45 of Set 11 | dezhou
# Processing Record 46 of Set 11 | requena
# Processing Record 47 of Set 11 | kamenskiy
# Processing Record 48 of Set 11 | finsterwalde
# Processing Record 49 of Set 11 | kholm
# Processing Record 0 of Set 12 | svodna
# Processing Record 1 of Set 12 | sakakah
# Processing Record 2 of Set 12 | sable-sur-sarthe
# Processing Record 3 of Set 12 | cayeli
# Processing Record 4 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 12 | ngama
# Processing Record 6 of Set 12 | manadhoo
# Processing Record 7 of Set 12 | tanout
# Processing Record 8 of Set 12 | viedma
# Processing Record 9 of Set 12 | dauphin
# Processing Record 10 of Set 12 | cam ranh
# Processing Record 11 of Set 12 | havoysund
# Processing Record 12 of Set 12 | stephenville crossing
# Processing Record 13 of Set 12 | jinka
# Processing Record 14 of Set 12 | artigas
# Processing Record 15 of Set 12 | boende
# Processing Record 16 of Set 12 | amapa
# Processing Record 17 of Set 12 | nelson
# Processing Record 18 of Set 12 | aswan
# Processing Record 19 of Set 12 | lincoln
# Processing Record 20 of Set 12 | moss vale
# Processing Record 21 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 23 of Set 12 | hibbing
# Processing Record 24 of Set 12 | marrakesh
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | villa sandino
# Processing Record 27 of Set 12 | ambalavao
# Processing Record 28 of Set 12 | nizhnyaya omka
# Processing Record 29 of Set 12 | naze
# Processing Record 30 of Set 12 | great yarmouth
# Processing Record 31 of Set 12 | gwadar
# Processing Record 32 of Set 12 | rapid valley
# Processing Record 33 of Set 12 | somanda
# Processing Record 34 of Set 12 | yuci
# Processing Record 35 of Set 12 | garm
# City not found. Skipping...
# Processing Record 36 of Set 12 | sterling
# Processing Record 37 of Set 12 | popondetta
# Processing Record 38 of Set 12 | kaz
# Processing Record 39 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 12 | wamba
# Processing Record 41 of Set 12 | miri
# Processing Record 42 of Set 12 | bentiu
# Processing Record 43 of Set 12 | minas
# Processing Record 44 of Set 12 | coahuayana
# Processing Record 45 of Set 12 | kokoda
# Processing Record 46 of Set 12 | pogradec
# Processing Record 47 of Set 12 | clarksburg
# Processing Record 48 of Set 12 | gushikawa
# Processing Record 49 of Set 12 | harrisonburg
# Processing Record 0 of Set 13 | pangnirtung
# Processing Record 1 of Set 13 | manavalakurichi
# Processing Record 2 of Set 13 | lazaro cardenas
# Processing Record 3 of Set 13 | waconia
# Processing Record 4 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 13 | christchurch
# Processing Record 6 of Set 13 | vila velha
# Processing Record 7 of Set 13 | swan river
# Processing Record 8 of Set 13 | tevriz
# Processing Record 9 of Set 13 | zlobin
# Processing Record 10 of Set 13 | faro
# Processing Record 11 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 13 | davidson
# Processing Record 13 of Set 13 | melekhovskaya
# City not found. Skipping...
# Processing Record 14 of Set 13 | port perry
# Processing Record 15 of Set 13 | warkworth
# Processing Record 16 of Set 13 | gilgit
# Processing Record 17 of Set 13 | banyo
# Processing Record 18 of Set 13 | germantown
# Processing Record 19 of Set 13 | whitianga
# Processing Record 20 of Set 13 | nikolsk
# Processing Record 21 of Set 13 | deputatskiy
# Processing Record 22 of Set 13 | talnakh
# Processing Record 23 of Set 13 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 24 of Set 13 | pastavy
# Processing Record 25 of Set 13 | along
# Processing Record 26 of Set 13 | saint-pierre
# Processing Record 27 of Set 13 | helong
# Processing Record 28 of Set 13 | kemerovo
# Processing Record 29 of Set 13 | bambanglipuro
# Processing Record 30 of Set 13 | privokzalnyy
# City not found. Skipping...
# Processing Record 31 of Set 13 | chowchilla
# Processing Record 32 of Set 13 | homer
# Processing Record 33 of Set 13 | marang
# Processing Record 34 of Set 13 | tessalit
# Processing Record 35 of Set 13 | praia da vitoria
# Processing Record 36 of Set 13 | olenino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  college  64.8569 -147.8028    -26.06        72          40        0.00
# 1   kidero  42.1932   45.9614     -7.77        91          97        0.77
# 2     chuy -33.6971  -53.4616     25.90        49          12        4.96
# 3  rikitea -23.1203 -134.9692     25.88        75           8        7.17
# 4   jardim -21.4803  -56.1381     32.10        45          37        1.12
#
#   Country        Date
# 0      US  1675615498
# 1      RU  1675615642
# 2      UY  1675615517
# 3      PF  1675615473
# 4      BR  1675615645

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        college  64.8569 -147.8028    -26.06        72          40
# 1         kidero  42.1932   45.9614     -7.77        91          97
# 2           chuy -33.6971  -53.4616     25.90        49          12
# 3        rikitea -23.1203 -134.9692     25.88        75           8
# 4         jardim -21.4803  -56.1381     32.10        45          37
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      US  1675615498
# 1              0.77      RU  1675615642
# 2              4.96      UY  1675615517
# 3              7.17      PF  1675615473
# 4              1.12      BR  1675615645

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title("City Latitude vs. Max Temperature (2023-2-4)")
plt.grid(visible=True, which='major', axis='both')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel("Humidity %")
plt.title("City Latitude vs. Humidity (2023-2-4)")
plt.grid(visible=True, which='major', axis='both')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel("Cloudiness %")
plt.title("City Latitude vs. Cloudiness (2023-2-4)")
plt.grid(visible=True, which='major', axis='both')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-2-4)")
plt.grid(visible=True, which='major', axis='both')


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
regress = stats.linregress

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            college  64.8569 -147.8028    -26.06        72          40
# 1             kidero  42.1932   45.9614     -7.77        91          97
# 6        keti bandar  24.1447   67.4497     21.96        78           0
# 8              nadym  65.5333   72.5167    -23.93       100          96
# 12             kapaa  22.0752 -159.3190     22.18        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      US  1675615498
# 1              0.77      RU  1675615642
# 6              5.25      PK  1675615649
# 8              1.03      RU  1675615652
# 12             3.60      US  1675615653

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2            chuy -33.6971  -53.4616     25.90        49          12
# 3         rikitea -23.1203 -134.9692     25.88        75           8
# 4          jardim -21.4803  -56.1381     32.10        45          37
# 5          hobart -42.8794  147.3294     14.47        77          95
# 7        coquimbo -29.9533  -71.3436     22.85        60           0
#
#          Wind Speed Country        Date
# City_ID
# 2              4.96      UY  1675615517
# 3              7.17      PF  1675615473
# 4              1.12      BR  1675615645
# 5              3.60      AU  1675615646
# 7              6.17      CL  1675615382

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value,regress_value,"r-")

plt.xlabel('Latitude')
plt.ylabel("Max Temp")
plt.text(0, -10, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.752700681333132

# %%
# Linear regression on Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "r-")

plt.xlabel('Latitude')
plt.ylabel("Max Temp")
plt.text(-18, 10, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.19732962991375924

# %% [raw]
# **Discussion about the linear relationship:** In the northern hemisphere, there appears to be a strong correlation between an increase in latitude and a decrease in max temperature. In the southern hemisphere, there appears to be a somewhat weak correlation between the increase latitude and a increase in max temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value,regress_value,"r-")

plt.xlabel('Latitude')
plt.ylabel("Humidity")
plt.text(52, 30, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.18109034310833688

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "r-")

plt.xlabel('Latitude')
plt.ylabel("Humidity")
plt.text(-15, 30, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.025332768628703928

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there appears to be a somewhat weak correlation between an increase in latitude and a increase in humidity. In the southern hemisphere, there appears to be an extremely weak correlation between the increase latitude and a increase in humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value,regress_value,"r-")

plt.xlabel('Latitude')
plt.ylabel("Cloudiness")
plt.text(60, 55, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.04493025403008179

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "r-")

plt.xlabel('Latitude')
plt.ylabel("Cloudiness")
plt.text(-55, 60, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.11338445663418775

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there appears to be a very weak correlation between an increase in latitude and a increase in cloudiness. In the southern hemisphere, there appears to be an fairly weak correlation between the increase latitude and a increase in cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value,regress_value,"r-")

plt.xlabel('Latitude')
plt.ylabel("Wind Speed")
plt.text(2, 14, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.0031304978370884817

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = regress(x_value, y_value)
regress_value = x_value * slope + intercept
equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "r-")

plt.xlabel('Latitude')
plt.ylabel("Wind Speed")
plt.text(-17, 13, equation)
print(f'The r-value is: {rvalue**2}')

plt.show()
# Out:
# The r-value is: 0.15902112498796186

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there appears to be a extremely weak correlation between an increase in latitude and a increase in wind spped. In the southern hemisphere, there appears to be an  weak correlation between the increase latitude and a increase in cloudiness.
